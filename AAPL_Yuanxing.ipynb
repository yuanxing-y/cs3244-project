# %% [markdown]
# #  Test on Apple Stock Data (AAPL)

# %% [markdown]
# Reference (continue to be updated):
# - https://www.analyticsvidhya.com/blog/2018/10/predicting-stock-price-machine-learningnd-deep-learning-techniques-python/

# %%
# import packages
import pandas as pd
import numpy as np

# to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

# for normalizing data (why?)
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler(feature_range=(0, 1))

# read the file
df = pd.read_csv('datasets/stocks/AAPL.csv')

# print the tail
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 9904  2020-03-26  246.520004  258.679993  246.360001  258.440002  258.440002
# 9905  2020-03-27  252.750000  255.869995  247.050003  247.740005  247.740005
# 9906  2020-03-30  250.740005  255.520004  249.399994  254.809998  254.809998
# 9907  2020-03-31  255.600006  262.489990  252.000000  254.289993  254.289993
# 9908  2020-04-01  246.500000  248.720001  239.130005  240.910004  240.910004
#
#         Volume
# 9904  63021800
# 9905  51054200
# 9906  41994100
# 9907  49250500
# 9908  43956200

# %%
#setting index as date
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')

# %% [markdown]
# From the above graph, data before 2005 (or 2010) doesn't seem to be very representive.
